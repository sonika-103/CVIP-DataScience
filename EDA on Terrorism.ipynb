# %% [markdown]
# ### Terrorism Around The World

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Terrorism=pd.read_csv("C:\\Users\\sonik\\Downloads\\globalterrorismdb_0718dist.csv", encoding="latin1")
Terrorism.head()
# Out:
# C:\Users\sonik\AppData\Local\Temp\ipykernel_3572\456077165.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   Terrorism=pd.read_csv("C:\\Users\\sonik\\Downloads\\globalterrorismdb_0718dist.csv", encoding="latin1")
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
Terrorism.shape
# Out:
# (181691, 135)

# %%
Terrorism.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
pd.set_option("display.max_columns", None)
Terrorism
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region                   region_txt  \
# ...

# %%
Terrorism.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region                  region_txt  \
# 181686      182      Somalia      11          Sub-Saharan Africa
# 181687      200        Syria      10  Middle East & North Africa
# 181688      160  Philippines       5              Southeast Asia
# 181689       92        India       6                  South Asia
# 181690      160  Philippines       5              Southeast Asia
#
#               provstate           city   latitude   longitude  specificity  \
# ...

# %%
Terrorism.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
Terrorism.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
Terrorism.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
Terrorism.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)
Terrorism
# Out:
#              eventid  Year  Month  Day approxdate  extended resolution  \
# 0       197000000001  1970      7    2        NaN         0        NaN
# 1       197000000002  1970      0    0        NaN         0        NaN
# 2       197001000001  1970      1    0        NaN         0        NaN
# 3       197001000002  1970      1    0        NaN         0        NaN
# 4       197001000003  1970      1    0        NaN         0        NaN
# ...              ...   ...    ...  ...        ...       ...        ...
# 181686  201712310022  2017     12   31        NaN         0        NaN
# 181687  201712310029  2017     12   31        NaN         0        NaN
# 181688  201712310030  2017     12   31        NaN         0        NaN
# 181689  201712310031  2017     12   31        NaN         0        NaN
# 181690  201712310032  2017     12   31        NaN         0        NaN
#
#         country             Country  region                       Region  \
# ...

# %%
null_columns = Terrorism.columns[Terrorism.isnull().any()]
print("Columns with null values:")
print(null_columns)
# Out:
# Columns with null values:
# Index(['approxdate', 'resolution', 'provstate', 'city', 'latitude',
#        'longitude', 'specificity', 'location', 'Summary', 'doubtterr',
#        ...
#        'ransompaidus', 'ransomnote', 'hostkidoutcome', 'hostkidoutcome_txt',
#        'nreleased', 'addnotes', 'scite1', 'scite2', 'scite3', 'related'],
#       dtype='object', length=106)

# %%
null_columns = Terrorism.columns[Terrorism.isnull().all()]
print("Columns with null values:")
print(null_columns)
# Out:
# Columns with null values:
# Index([], dtype='object')

# %%
Terror=Terrorism[['Year','Month','Day','Country','Region','city','latitude','longitude','AttackType','Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]
Terrorism['casualities']=Terrorism['Killed']+Terrorism['Wounded']
Terror
# Out:
#         Year  Month  Day             Country                       Region  \
# 0       1970      7    2  Dominican Republic  Central America & Caribbean
# 1       1970      0    0              Mexico                North America
# 2       1970      1    0         Philippines               Southeast Asia
# 3       1970      1    0              Greece               Western Europe
# 4       1970      1    0               Japan                    East Asia
# ...      ...    ...  ...                 ...                          ...
# 181686  2017     12   31             Somalia           Sub-Saharan Africa
# 181687  2017     12   31               Syria   Middle East & North Africa
# 181688  2017     12   31         Philippines               Southeast Asia
# 181689  2017     12   31               India                   South Asia
# 181690  2017     12   31         Philippines               Southeast Asia
#
#                  city   latitude   longitude                      AttackType  \
# ...

# %%
Terror.shape
# Out:
# (181691, 17)

# %%
Terror.describe()
# Out:
#                 Year          Month            Day       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           longitude         Killed        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# ...

# %%
Terror.describe().T
# Out:
#               count         mean            std           min          25%  \
# Year       181691.0  2002.638997      13.259430  1.970000e+03  1991.000000
# Month      181691.0     6.467277       3.388303  0.000000e+00     4.000000
# Day        181691.0    15.505644       8.814045  0.000000e+00     8.000000
# latitude   177135.0    23.498343      18.569242 -5.315461e+01    11.510046
# longitude  177134.0  -458.695653  204778.988611 -8.618590e+07     4.545640
# Killed     171378.0     2.403272      11.545741  0.000000e+00     0.000000
# Wounded    165380.0     3.167668      35.949392  0.000000e+00     0.000000
#
#                    50%          75%          max
# Year       2009.000000  2014.000000  2017.000000
# Month         6.000000     9.000000    12.000000
# Day          15.000000    23.000000    31.000000
# latitude     31.467463    34.685087    74.633553
# longitude    43.246506    68.710327   179.366667
# Killed        0.000000     2.000000  1570.000000
# ...

# %%
Terror.corr()
# Out:
#                Year     Month       Day  latitude  longitude    Killed  \
# Year       1.000000  0.000139  0.018254  0.166933   0.003917  0.015341
# Month      0.000139  1.000000  0.005497 -0.015978  -0.003880  0.003463
# Day        0.018254  0.005497  1.000000  0.003423  -0.002285 -0.003693
# latitude   0.166933 -0.015978  0.003423  1.000000   0.001463 -0.018124
# longitude  0.003917 -0.003880 -0.002285  0.001463   1.000000 -0.000562
# Killed     0.015341  0.003463 -0.003693 -0.018124  -0.000562  1.000000
# Wounded    0.015273  0.002938 -0.001268  0.015988   0.000223  0.534375
#
#             Wounded
# Year       0.015273
# Month      0.002938
# Day       -0.001268
# latitude   0.015988
# longitude  0.000223
# Killed     0.534375
# Wounded    1.000000

# %%
np.round(Terror.corr(),2)
# Out:
#            Year  Month   Day  latitude  longitude  Killed  Wounded
# Year       1.00   0.00  0.02      0.17        0.0    0.02     0.02
# Month      0.00   1.00  0.01     -0.02       -0.0    0.00     0.00
# Day        0.02   0.01  1.00      0.00       -0.0   -0.00    -0.00
# latitude   0.17  -0.02  0.00      1.00        0.0   -0.02     0.02
# longitude  0.00  -0.00 -0.00      0.00        1.0   -0.00     0.00
# Killed     0.02   0.00 -0.00     -0.02       -0.0    1.00     0.53
# Wounded    0.02   0.00 -0.00      0.02        0.0    0.53     1.00

# %%
sns.heatmap(np.round(Terror.corr(),2), annot=True)
# Out:
# <AxesSubplot:>

# %%
Terror.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# Region              0
# city              434
# latitude         4556
# longitude        4557
# AttackType          0
# Killed          10313
# Wounded         16311
# Target            636
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# dtype: int64

# %%
print('Country with Highest Terrorist Attacks:',Terror['Country'].value_counts().index[0])
# Out:
# Country with Highest Terrorist Attacks: Iraq

# %%
print('Regions with Highest Terrorist Attacks:',Terror['Region'].value_counts().index[0])
# Out:
# Regions with Highest Terrorist Attacks: Middle East & North Africa

# %%
print('Maximum people killed in an attack are:',Terror['Killed'].max(),'that took place in',Terror.loc[Terror['Killed'].idxmax()].Country)
# Out:
# Maximum people killed in an attack are: 1570.0 that took place in Iraq

# %%
Terror['Year']
# Out:
# 0         1970
# 1         1970
# 2         1970
# 3         1970
# 4         1970
#           ...
# 181686    2017
# 181687    2017
# 181688    2017
# 181689    2017
# 181690    2017
# Name: Year, Length: 181691, dtype: int64

# %%
plt.figure(figsize=(40,20))
sns.countplot('Year',data=Terror)
plt.title('Number Of Terrorist Activities Each Year')
plt.show()
# Out:
# C:\Users\sonik\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(40,20))
sns.countplot('AttackType',data=Terror, color='Green')
plt.title('Attacking Method by Terrorists')
plt.show()
# Out:
# C:\Users\sonik\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(40,20))
sns.countplot('AttackType',data=Terror, palette='rocket', order=Terror['AttackType'].value_counts().index)
plt.title('Attacking Method by Terrorists')
plt.show()
# Out:
# C:\Users\sonik\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(40,20))
sns.countplot('Target_type',data=Terror, order=Terror['Target_type'].value_counts().index)
plt.title('Target Preferences of Terrorists')
plt.show()

# %%
plt.figure(figsize=(40,20))
sns.countplot('Country',data=Terror, order=Terror['Country'].value_counts().index)
plt.title('Most affected Countries')
plt.show()
# Out:
# C:\Users\sonik\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=Terror['Country'].value_counts()[:15].index,
            y=Terror['Country'].value_counts()[:15].values,
            palette='inferno')
plt.title('Most affected Countries')
plt.show()

# %%
plt.figure(figsize=(40,20))
sns.countplot('Region',data=Terror, order=Terror['Region'].value_counts().index)
plt.title('Number of terrorist activities in the region')
plt.show()
# Out:
# C:\Users\sonik\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
Terror_region = pd.crosstab(Terror['Year'], Terror['Region'])
Terror_region.plot(kind='line')
plt.title('Number of terrorist activities in the region')
plt.show()

# %%
coun_Terror=Terror['Country'].value_counts()[:15].to_frame()
coun_Terror.columns=['Attacks']
coun_kill=Terror.groupby('Country')['Killed'].sum().to_frame()
coun_Terror.merge(coun_kill,left_index=True,right_index=True,how='left').plot.bar(width=0.9)
fig=plt.gcf()
fig.set_size_inches(18,6)
plt.show()

# %%
sns.barplot(Terror['Group'].value_counts()[1:15].values,Terror['Group'].value_counts()[1:15].index,palette=('inferno'))
plt.title('Terrorists Groups')
plt.show()
# Out:
# C:\Users\sonik\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
top_groups10=Terror[Terror['Group'].isin(Terror['Group'].value_counts()[1:11].index)]
pd.crosstab(top_groups10.Year,top_groups10.Group).plot(color=sns.color_palette('Paired',10))
fig.set_size_inches(10,6)
plt.show()
